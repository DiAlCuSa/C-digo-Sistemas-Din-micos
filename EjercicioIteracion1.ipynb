# %% [markdown]
# # Ejercicio de iteración
#
# \begin{equation}
#     x_{t+1}=R(1-x_t)x_t
# \end{equation}
#
# Con solución
# \begin{equation}
#     X_{t}=R^t x_0 --X(t)=R^t x_0
# \end{equation}

# %%
import scipy as sc
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# Iterar ambas funciones, una como una función recursiva y la otra como función de t para diferentes valores de R
# Describir el comportamiento
#
# Hacer una lista y compararlas y graficar

# %%
R=[0.5,0.6,0.8,0.9]
x0=0.9

x=[]
for j in range(len(R)):
    x1=[]
    x1.append(x0)
    for i in range(0,200):
        x1.append(R[j]*(1-x1[i])*x1[i])
    x.append(x1)  
print(x)
# Out:
# [[0.9, 0.04499999999999999, 0.021487499999999996, 0.010512893671874999, 0.005201186369259424, 0.0025870670148058273, 0.0012901870495333654, 0.0006442612334552909, 0.0003219230804591788, 0.00016090972299472324, 8.04419155278845e-05, 4.0217722313055354e-05, 2.010805242393365e-05, 1.0053824045080683e-05, 5.026861482851377e-06, 2.5134181067575047e-06, 1.2567058947434626e-06, 6.283521577168784e-07, 3.1417588144522213e-07, 1.5708789136936882e-07, 7.85439333463816e-08, 3.9271963588616067e-08, 1.963598102316447e-08, 9.81799031879636e-09, 4.908995111201713e-09, 2.4544975435517402e-09, 1.227248768763591e-09, 6.136243836287257e-10, 3.068121916260954e-10, 1.5340609576598085e-10, 7.670304787122371e-11, 3.8351523932670176e-11, 1.917576196559967e-11, 9.58788098261598e-12, 4.793940491262026e-12, 2.3969702456195223e-12, 1.1984851228068884e-12, 5.99242561402726e-13, 2.9962128070118346e-13, 1.4981064035054685e-13, 7.49053201752622e-14, 3.745266008762829e-14, 1.8726330043813446e-14, 9.363165021906548e-1
# ...

# %%
for i in range(len(x)):
    plt.plot(x[i], label=i)
    plt.legend()
